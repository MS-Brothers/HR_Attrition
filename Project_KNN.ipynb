# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('HR.csv')

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   str
#  2   BusinessTravel            1470 non-null   str
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   str
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   str
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   str
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data['Attrition'].value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
data['BusinessTravel'].value_counts() 
# Why not label encoding
# It will convert:
# Non-Travel → 0
# Travel_Frequently → 1
# Travel_Rarely → 2
# This creates a fake numerical relationship, which is wrong for correlation heatmap.
# Out:
# BusinessTravel
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: count, dtype: int64

# %%
data['Department'].value_counts()
# Out:
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64

# %%
data['EducationField'].value_counts()
# Out:
# EducationField
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: count, dtype: int64

# %%
data['Attrition'] = data['Attrition'].replace({"No":0,"Yes":1})
# data=pd.get_dummies(data,columns=['BusinessTravel'],drop_first=False)

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41         1      Travel_Rarely       1102                   Sales
# 1   49         0  Travel_Frequently        279  Research & Development
# 2   37         1      Travel_Rarely       1373  Research & Development
# 3   33         0  Travel_Frequently       1392  Research & Development
# 4   27         0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
# I want to find mere dataset me kitne categorical column hai
print(data.select_dtypes(include='object').columns)
# pandas store string as a onject

# print(data.select_dtypes(include=['object','string']).columns)

#pandas support new type called string so not give the warning
# print all categorical columns in my dataset
# Out:
# Index(['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender',
#        'JobRole', 'MaritalStatus', 'Over18', 'OverTime'],
#       dtype='str')
# C:\Users\user\AppData\Local\Temp\ipykernel_13308\3785628631.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   print(data.select_dtypes(include='object').columns)

# %%
data = pd.get_dummies(
    data,
    columns=data.select_dtypes(include=['object','string']).columns.drop('Attrition'),
    drop_first=True,
    dtype=int
)

# %%
data.head()
# Out:
#    Age Attrition  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0   41         1       1102                 1          2              1
# 1   49         0        279                 8          1              1
# 2   37         1       1373                 2          2              1
# 3   33         0       1392                 3          4              1
# 4   27         0        591                 2          1              1
#
#    EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  ...  \
# 0               1                        2          94               3  ...
# 1               2                        3          61               2  ...
# 2               4                        4          92               2  ...
# 3               5                        4          56               3  ...
# 4               7                        1          40               3  ...
#
#    JobRole_Laboratory Technician  JobRole_Manager  \
# ...

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt

# plt.figure(figsize=(50,30))
# sns.heatmap(data.corr(),annot=True,cmap='coolwarm')
# plt.show()

# %%
# Correlation with target
# corr_target = data.corr()['Attrition'].sort_values(ascending=False)

# print(corr_target)

# %%
data.drop(['EmployeeCount','StandardHours','EmployeeNumber'],axis=1,inplace=True)

# %%
# Scaling

# %%
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810   802.485714          9.192517     2.912925
# std       9.135373   403.509100          8.106864     1.024165
# min      18.000000   102.000000          1.000000     1.000000
# 25%      30.000000   465.000000          2.000000     2.000000
# 50%      36.000000   802.000000          7.000000     3.000000
# 75%      43.000000  1157.000000         14.000000     4.000000
# max      60.000000  1499.000000         29.000000     5.000000
#
#        EnvironmentSatisfaction   HourlyRate  JobInvolvement     JobLevel  \
# count              1470.000000  1470.000000     1470.000000  1470.000000
# mean                  2.721769    65.891156        2.729932     2.063946
# std                   1.093082    20.329428        0.711561     1.106940
# min                   1.000000    30.000000        1.000000     1.000000
# ...

# %%
# Imblanced Data
data['Attrition'].value_counts()
# Out:
# Attrition
# 0    1233
# 1     237
# Name: count, dtype: int64

# %%
# checking outliers

# %%
# def checkOutlier(data, col):
#     plt.subplot(1,2,1)
#     plt.boxplot(data[col])
#     plt.subplot(1,2,2)
#     sns.histplot(data=data, x=col,kde=True)
#     plt.axvline(data[col].mean()+(3*data[col].std()),color='red')
#     plt.axvline(data[col].mean()-(3*data[col].std()),color='red')

# %%
def checkOutlier(data, col=None):
    
    if col is None:
        cols = data.select_dtypes(include='number').columns
    else:
        cols = [col]
    
    for c in cols:
        plt.figure(figsize=(10,4))
        
        plt.subplot(1,2,1)
        plt.boxplot(data[c])
        plt.title(f'Boxplot of {c}')
        
        plt.subplot(1,2,2)
        sns.histplot(data=data, x=c, kde=True)
        plt.axvline(data[c].mean() + (3 * data[c].std()), color='red')
        plt.axvline(data[c].mean() - (3 * data[c].std()), color='red')
        plt.title(f'Distribution of {c}')
        
        plt.tight_layout()
        plt.show()

# %%
# for col in data.select_dtypes(include='number').columns:
#     checkOutlier(data, col)

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'DailyRate', 'DistanceFromHome', 'Education',
#        'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel',
#        'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager',
#        'BusinessTravel_Travel_Frequently', 'BusinessTravel_Travel_Rarely',
#        'Department_Research & Development', 'Department_Sales',
#        'EducationField_Life Sciences', 'EducationField_Marketing',
#        'EducationField_Medical', 'EducationField_Other',
#        'EducationField_Technical Degree', 'Gender_Male',
#        'JobRole_Human Resources', 'JobRole_Laboratory Technician',
#        'JobRole_Manager', 'JobRole_Manufacturing Director',
# ...

# %%
col = "TotalWorkingYears"

mean = data[col].mean()
std = data[col].std()

upper = mean + 3 * std
lower = mean - 3 * std

data["Outlier_Flag"] = data[col].apply(
    lambda x: "Outlier" if (x > upper or x < lower) else "Normal"
)
data = data[data["Outlier_Flag"] == "Normal"]
data["Outlier_Flag"].value_counts()
# Out:
# Outlier_Flag
# Normal    1454
# Name: count, dtype: int64

# %%
col = "YearsAtCompany"

mean = data[col].mean()
std = data[col].std()

upper = mean + 3 * std
lower = mean - 3 * std

data["Outlier_Flag"] = data[col].apply(
    lambda x: "Outlier" if (x > upper or x < lower) else "Normal"
)
data = data[data["Outlier_Flag"] == "Normal"]
data["Outlier_Flag"].value_counts()
# Out:
# Outlier_Flag
# Normal    1430
# Name: count, dtype: int64

# %%
col = "YearsInCurrentRole"

mean = data[col].mean()
std = data[col].std()

upper = mean + 3 * std
lower = mean - 3 * std

data["Outlier_Flag"] = data[col].apply(
    lambda x: "Outlier" if (x > upper or x < lower) else "Normal"
)
data = data[data["Outlier_Flag"] == "Normal"]
data["Outlier_Flag"].value_counts()
# Out:
# Outlier_Flag
# Normal    1413
# Name: count, dtype: int64

# %%
col = "YearsSinceLastPromotion"

mean = data[col].mean()
std = data[col].std()

upper = mean + 3 * std
lower = mean - 3 * std

data["Outlier_Flag"] = data[col].apply(
    lambda x: "Outlier" if (x > upper or x < lower) else "Normal"
)

data["Outlier_Flag"].value_counts()
data = data[data["Outlier_Flag"] == "Normal"]

# %%
data["Outlier_Flag"].value_counts()
# Out:
# Outlier_Flag
# Normal    1370
# Name: count, dtype: int64

# %%
col = "YearsWithCurrManager"

mean = data[col].mean()
std = data[col].std()

upper = mean + 3 * std
lower = mean - 3 * std

data["Outlier_Flag"] = data[col].apply(
    lambda x: "Outlier" if (x > upper or x < lower) else "Normal"
)
data = data[data["Outlier_Flag"] == "Normal"]
data["Outlier_Flag"].value_counts()
# Out:
# Outlier_Flag
# Normal    1363
# Name: count, dtype: int64

# %%
data.head()
# Out:
#    Age Attrition  DailyRate  DistanceFromHome  Education  \
# 0   41         1       1102                 1          2
# 1   49         0        279                 8          1
# 2   37         1       1373                 2          2
# 3   33         0       1392                 3          4
# 4   27         0        591                 2          1
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2          94               3         2
# 1                        3          61               2         2
# 2                        4          92               2         1
# 3                        4          56               3         1
# 4                        1          40               3         1
#
#    JobSatisfaction  ...  JobRole_Manager  JobRole_Manufacturing Director  \
# 0                4  ...                0                               0
# 1                2  ...                0                               0
# ...

# %%
data = data.drop("Outlier_Flag", axis=1)

# %%
data.head()
# Out:
#    Age Attrition  DailyRate  DistanceFromHome  Education  \
# 0   41         1       1102                 1          2
# 1   49         0        279                 8          1
# 2   37         1       1373                 2          2
# 3   33         0       1392                 3          4
# 4   27         0        591                 2          1
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2          94               3         2
# 1                        3          61               2         2
# 2                        4          92               2         1
# 3                        4          56               3         1
# 4                        1          40               3         1
#
#    JobSatisfaction  ...  JobRole_Laboratory Technician  JobRole_Manager  \
# 0                4  ...                              0                0
# 1                2  ...                              0                0
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1363 entries, 0 to 1469
# Data columns (total 45 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                1363 non-null   int64
#  1   Attrition                          1363 non-null   object
#  2   DailyRate                          1363 non-null   int64
#  3   DistanceFromHome                   1363 non-null   int64
#  4   Education                          1363 non-null   int64
#  5   EnvironmentSatisfaction            1363 non-null   int64
#  6   HourlyRate                         1363 non-null   int64
#  7   JobInvolvement                     1363 non-null   int64
#  8   JobLevel                           1363 non-null   int64
#  9   JobSatisfaction                    1363 non-null   int64
#  10  MonthlyIncome                      1363 non-null   int64
#  11  MonthlyRate                        1363 non-null   int64
# ...

# %%
data['Attrition'].value_counts()
# Out:
# Attrition
# 0    1136
# 1     227
# Name: count, dtype: int64

# %%
# data["Attrition"] = data["Attrition"].map({"No": 0, "Yes": 1})

# %%
X = data.drop("Attrition", axis=1)
y = data["Attrition"]
y = y.astype(int)

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE()
X_sm, y_sm = sm.fit_resample(X, y)

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
X_train_scaled = ss.fit_transform(X_sm)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_train_scaled, y_sm, test_size=0.3, random_state=42)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_train_scaled, y_sm,
    test_size=0.2,
    random_state=42,
)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_validate

# %%
knn = KNeighborsClassifier()
result = cross_validate(knn, X_train, y_train)
result['test_score'].mean()
# knn_model = knn.fit(X_train, y_train)
# Out:
# 0.8761768534495807

# %%
from sklearn.model_selection import GridSearchCV

knn = KNeighborsClassifier()
parameters = {'n_neighbors' : np.arange(3,16,2),
               'metric' :['euclidean', 'cosine', 'manhattan', 'minkowski']}
gcv = GridSearchCV(estimator=knn, param_grid=parameters)
result =gcv.fit(X_train,y_train)

# %%
# knn_model = gcv.fit(X_train, y_train)

# %%
train_pred = gcv.predict(X_train)
test_pred = gcv.predict(X_test)
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
test_acc = accuracy_score(y_test, test_pred)
train_acc = accuracy_score(y_train, train_pred)
print('Training Accuracy : ', train_acc)
print('Testing Accuracy : ', test_acc)
# Out:
# Training Accuracy :  0.9284534947716016
# Testing Accuracy :  0.9032967032967033

# %%
# Hyperparameter tunning

# %%
gcv.best_params_
# Out:
# {'metric': 'cosine', 'n_neighbors': 9}

# %%
# Confusion matrix code

# %%
confusion_matrix(y_test, test_pred)
# Out:
# array([[208,  17],
#        [ 27, 203]], dtype=int64)

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
gcv.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=KNeighborsClassifier(),
#              param_grid={'metric': ['euclidean', 'cosine', 'manhattan',
#                                     'minkowski'],
#                          'n_neighbors': array([ 3,  5,  7,  9, 11, 13, 15])})

# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_validate


y_train_pred=gcv.predict(X_train)
train_accuracy = accuracy_score(y_train, y_train_pred)
# result = cross_validate(knn, X_train, y_train)
y_test_pred = gcv.predict(X_test)
test_accuracy = accuracy_score(y_test, y_test_pred)
print("Training Accuracy:", train_accuracy)
print("Testing Accuracy:", test_accuracy)
# Out:
# Training Accuracy: 0.9284534947716016
# Testing Accuracy: 0.9032967032967033

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,test_pred)
# Out:
# array([[208,  17],
#        [ 27, 203]], dtype=int64)

# %%
print(classification_report(y_test, test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.92      0.90       225
#            1       0.92      0.88      0.90       230
#
#     accuracy                           0.90       455
#    macro avg       0.90      0.90      0.90       455
# weighted avg       0.90      0.90      0.90       455

# %%
import pickle
with open("attrition_model.pkl", "wb") as f:
    pickle.dump(gcv, f)
